# %%
import pandas as pd

# %%
df = pd.read_csv("ensembled_results_DistilBert.csv")

# %%
df.head()
# Out:
#                                              prompts  labels  predictions  \
# 0  Okay, thanks. I'm interested in this central-w...       0            0
# 1  I need to make about 2 dozen peanut butter coo...       0            0
# 2  What is the operational schedule for Times Squ...       0            0
# 3  Okay, thanks for those details. Now can you li...       0            0
# 4  Do you know how much this subscription cost mo...       0            0
#
#    entropies           logits_model_0           logits_model_1  \
# 0   0.029188  [ 2.7239234 -2.964329 ]  [ 3.1967647 -2.591419 ]
# 1   0.034354  [ 2.7816293 -2.2193227]  [ 3.3958457 -2.4702382]
# 2   0.004458  [ 4.2445517 -3.8609278]  [ 3.8910244 -3.167998 ]
# 3   0.022854    [ 3.507315 -3.678008]  [ 3.0491889 -2.3829496]
# 4   0.005981  [ 4.2106166 -3.7521245]  [ 3.8450868 -3.129209 ]
#
#             logits_model_2           logits_model_3           logits_model_4  \
# ...

# %%
# sort from highest to lowest entropy (most uncertain to least uncertain)
sorted = df.sort_values(by=['entropies'], ascending=False)
